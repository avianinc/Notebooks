# %%
import time
import subprocess
import os
from watchdog.observers import Observer
from watchdog.events import FileSystemEventHandler
from apscheduler.schedulers.background import BackgroundScheduler
import logging

# Setup logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# User-defined variables
DIRECTORY = r"C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\"
NOTEBOOK_FILE = "pull_vendor_api.ipynb"
JSON_FILE = "VendorA.json"
PIPELINE_FILE = "update_box.pipeline"

# Enable test mode
TEST_MODE = False

class ChangeHandler(FileSystemEventHandler):
    def __init__(self):
        self.file_changed = False

    def on_modified(self, event):
        if event.src_path == f"{DIRECTORY}{JSON_FILE}":
            logging.info(f"File {event.src_path} has been modified")
            self.file_changed = True

def run_notebook():
    logging.info("Executing notebook to pull API data...")
    result = subprocess.run(
        ["jupyter", "nbconvert", "--to", "notebook", "--execute", "--inplace", f"{DIRECTORY}{NOTEBOOK_FILE}"],
        capture_output=True, text=True)
    logging.info("Notebook execution completed.")
    if "Writing" in result.stderr:  # Check if it's a standard nbconvert output
        logging.info(f"Notebook Update: {result.stderr}")
    elif result.stderr:
        logging.error(f"Notebook Errors: {result.stderr}")

def check_and_run_pipeline():
    if event_handler.file_changed and not check_and_run_pipeline.is_running:
        check_and_run_pipeline.is_running = True
        logging.info("Change detected in JSON file, initiating Elyra pipeline...")
        
        pipeline_path = f"{DIRECTORY}{PIPELINE_FILE}"
        command = ["elyra-pipeline", "run", pipeline_path]
        
        if os.path.exists(pipeline_path):
            result = subprocess.run(command, capture_output=True, text=True)
            if result.stdout:
                logging.info(f"Pipeline Output: {result.stdout}")
            if result.stderr:
                logging.error(f"Pipeline Errors: {result.stderr}")
            if result.returncode != 0:
                logging.error("Failed to execute the pipeline.")
        else:
            logging.error(f"Pipeline file not found: {pipeline_path}")
        
        event_handler.file_changed = False
        check_and_run_pipeline.is_running = False
    else:
        logging.info("No changes detected in JSON file since last check or pipeline is still running.")

# Attach a flag to the function to monitor its running state
check_and_run_pipeline.is_running = False

if __name__ == "__main__":
    event_handler = ChangeHandler()
    observer = Observer()
    observer.schedule(event_handler, DIRECTORY, recursive=False)
    observer.start()

    scheduler = BackgroundScheduler()
    scheduler.add_job(run_notebook, 'interval', minutes=2)  # Adjusted to run every 2 minutes
    scheduler.add_job(check_and_run_pipeline, 'interval', minutes=2)
    scheduler.start()

    # Simulate a file change for testing purposes
    if TEST_MODE:
        time.sleep(5)  # Wait a few seconds before simulating
        logging.info("Test Mode: Simulating file change...")
        event_handler.file_changed = True  # Manually set the flag to simulate file change

    try:
        while True:
            time.sleep(1)
    except (KeyboardInterrupt, SystemExit):
        observer.stop()
        scheduler.shutdown()
    observer.join()
# Out:
# 2024-05-14 17:38:51,031 - INFO - Adding job tentatively -- it will be properly scheduled when the scheduler starts
# 2024-05-14 17:38:51,032 - INFO - Adding job tentatively -- it will be properly scheduled when the scheduler starts
# 2024-05-14 17:38:51,032 - INFO - Added job "run_notebook" to job store "default"
# 2024-05-14 17:38:51,033 - INFO - Added job "check_and_run_pipeline" to job store "default"
# 2024-05-14 17:38:51,034 - INFO - Scheduler started
# 2024-05-14 17:40:51,033 - INFO - Running job "run_notebook (trigger: interval[0:02:00], next run at: 2024-05-14 17:40:51 EDT)" (scheduled at 2024-05-14 17:40:51.030063-04:00)
# 2024-05-14 17:40:51,036 - INFO - Executing notebook to pull API data...
# 2024-05-14 17:40:51,035 - INFO - Running job "check_and_run_pipeline (trigger: interval[0:02:00], next run at: 2024-05-14 17:42:51 EDT)" (scheduled at 2024-05-14 17:40:51.032081-04:00)
# 2024-05-14 17:40:51,040 - INFO - No changes detected in JSON file since last check or pipeline is still running.
# 2024-05-14 17:40:51,041 - INFO - Job "check_and_run_pipeline (trigger: interval[0:02:00], next run at: 2024-05-14 17:42:51 EDT)" executed successfully
# 2024-05-14 17:41:03,779 - INFO - File C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\VendorA.json has been modified
# 2024-05-14 17:41:03,781 - INFO - File C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\VendorA.json has been modified
# 2024-05-14 17:41:04,478 - INFO - Notebook execution completed.
# 2024-05-14 17:41:04,480 - INFO - Notebook Update: [NbConvertApp] Converting notebook C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\pull_vendor_api.ipynb to notebook
# [NbConvertApp] Writing 45895 bytes to C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\pull_vendor_api.ipynb
#
# 2024-05-14 17:41:04,481 - INFO - Job "run_notebook (trigger: interval[0:02:00], next run at: 2024-05-14 17:42:51 EDT)" executed successfully
# 2024-05-14 17:42:51,044 - INFO - Running job "run_notebook (trigger: interval[0:02:00], next run at: 2024-05-14 17:44:51 EDT)" (scheduled at 2024-05-14 17:42:51.030063-04:00)
# 2024-05-14 17:42:51,044 - INFO - Running job "check_and_run_pipeline (trigger: interval[0:02:00], next run at: 2024-05-14 17:44:51 EDT)" (scheduled at 2024-05-14 17:42:51.032081-04:00)
# 2024-05-14 17:42:51,045 - INFO - Executing notebook to pull API data...
# 2024-05-14 17:42:51,046 - INFO - Change detected in JSON file, initiating Elyra pipeline...
# 2024-05-14 17:42:51,067 - ERROR - Job "check_and_run_pipeline (trigger: interval[0:02:00], next run at: 2024-05-14 17:44:51 EDT)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\JohnDeHart\anaconda3\envs\twc_api_interactions\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "C:\Users\JohnDeHart\AppData\Local\Temp\ipykernel_22164\2404736047.py", line 50, in check_and_run_pipeline
#     result = subprocess.run(command, capture_output=True, text=True)
#   File "C:\Users\JohnDeHart\anaconda3\envs\twc_api_interactions\lib\subprocess.py", line 503, in run
#     with Popen(*popenargs, **kwargs) as process:
#   File "C:\Users\JohnDeHart\anaconda3\envs\twc_api_interactions\lib\subprocess.py", line 971, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "C:\Users\JohnDeHart\anaconda3\envs\twc_api_interactions\lib\subprocess.py", line 1456, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
# PermissionError: [WinError 5] Access is denied
# 2024-05-14 17:43:04,170 - INFO - File C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\VendorA.json has been modified
# 2024-05-14 17:43:04,172 - INFO - File C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\VendorA.json has been modified
# 2024-05-14 17:43:04,738 - INFO - Notebook execution completed.
# 2024-05-14 17:43:04,739 - INFO - Notebook Update: [NbConvertApp] Converting notebook C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\pull_vendor_api.ipynb to notebook
# [NbConvertApp] Writing 45895 bytes to C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\pull_vendor_api.ipynb
#
# 2024-05-14 17:43:04,740 - INFO - Job "run_notebook (trigger: interval[0:02:00], next run at: 2024-05-14 17:44:51 EDT)" executed successfully
# 2024-05-14 17:44:51,043 - INFO - Running job "run_notebook (trigger: interval[0:02:00], next run at: 2024-05-14 17:46:51 EDT)" (scheduled at 2024-05-14 17:44:51.030063-04:00)
# 2024-05-14 17:44:51,044 - INFO - Executing notebook to pull API data...
# 2024-05-14 17:44:51,043 - INFO - Running job "check_and_run_pipeline (trigger: interval[0:02:00], next run at: 2024-05-14 17:46:51 EDT)" (scheduled at 2024-05-14 17:44:51.032081-04:00)
# 2024-05-14 17:44:51,046 - INFO - No changes detected in JSON file since last check or pipeline is still running.
# 2024-05-14 17:44:51,047 - INFO - Job "check_and_run_pipeline (trigger: interval[0:02:00], next run at: 2024-05-14 17:46:51 EDT)" executed successfully
# 2024-05-14 17:45:02,888 - INFO - File C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\VendorA.json has been modified
# 2024-05-14 17:45:03,436 - INFO - Notebook execution completed.
# 2024-05-14 17:45:03,437 - INFO - Notebook Update: [NbConvertApp] Converting notebook C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\pull_vendor_api.ipynb to notebook
# [NbConvertApp] Writing 45895 bytes to C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\pull_vendor_api.ipynb
#
# 2024-05-14 17:45:03,437 - INFO - Job "run_notebook (trigger: interval[0:02:00], next run at: 2024-05-14 17:46:51 EDT)" executed successfully
# 2024-05-14 17:46:51,040 - INFO - Running job "run_notebook (trigger: interval[0:02:00], next run at: 2024-05-14 17:48:51 EDT)" (scheduled at 2024-05-14 17:46:51.030063-04:00)
# 2024-05-14 17:46:51,041 - INFO - Executing notebook to pull API data...
# 2024-05-14 17:46:51,040 - INFO - Running job "check_and_run_pipeline (trigger: interval[0:02:00], next run at: 2024-05-14 17:48:51 EDT)" (scheduled at 2024-05-14 17:46:51.032081-04:00)
# 2024-05-14 17:46:51,043 - INFO - No changes detected in JSON file since last check or pipeline is still running.
# 2024-05-14 17:46:51,044 - INFO - Job "check_and_run_pipeline (trigger: interval[0:02:00], next run at: 2024-05-14 17:48:51 EDT)" executed successfully
# 2024-05-14 17:47:04,173 - INFO - File C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\VendorA.json has been modified
# 2024-05-14 17:47:04,175 - INFO - File C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\VendorA.json has been modified
# 2024-05-14 17:47:04,737 - INFO - Notebook execution completed.
# 2024-05-14 17:47:04,738 - INFO - Notebook Update: [NbConvertApp] Converting notebook C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\pull_vendor_api.ipynb to notebook
# [NbConvertApp] Writing 45911 bytes to C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\pull_vendor_api.ipynb
#
# 2024-05-14 17:47:04,739 - INFO - Job "run_notebook (trigger: interval[0:02:00], next run at: 2024-05-14 17:48:51 EDT)" executed successfully
# 2024-05-14 17:48:51,045 - INFO - Running job "run_notebook (trigger: interval[0:02:00], next run at: 2024-05-14 17:50:51 EDT)" (scheduled at 2024-05-14 17:48:51.030063-04:00)
# 2024-05-14 17:48:51,046 - INFO - Executing notebook to pull API data...
# 2024-05-14 17:48:51,046 - INFO - Running job "check_and_run_pipeline (trigger: interval[0:02:00], next run at: 2024-05-14 17:50:51 EDT)" (scheduled at 2024-05-14 17:48:51.032081-04:00)
# 2024-05-14 17:48:51,048 - INFO - No changes detected in JSON file since last check or pipeline is still running.
# 2024-05-14 17:48:51,048 - INFO - Job "check_and_run_pipeline (trigger: interval[0:02:00], next run at: 2024-05-14 17:50:51 EDT)" executed successfully
# 2024-05-14 17:49:03,379 - INFO - File C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\VendorA.json has been modified
# 2024-05-14 17:49:03,380 - INFO - File C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\VendorA.json has been modified
# 2024-05-14 17:49:03,931 - INFO - Notebook execution completed.
# 2024-05-14 17:49:03,932 - INFO - Notebook Update: [NbConvertApp] Converting notebook C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\pull_vendor_api.ipynb to notebook
# [NbConvertApp] Writing 45911 bytes to C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\pull_vendor_api.ipynb
#
# 2024-05-14 17:49:03,933 - INFO - Job "run_notebook (trigger: interval[0:02:00], next run at: 2024-05-14 17:50:51 EDT)" executed successfully
# 2024-05-14 17:50:51,042 - INFO - Running job "run_notebook (trigger: interval[0:02:00], next run at: 2024-05-14 17:52:51 EDT)" (scheduled at 2024-05-14 17:50:51.030063-04:00)
# 2024-05-14 17:50:51,043 - INFO - Running job "check_and_run_pipeline (trigger: interval[0:02:00], next run at: 2024-05-14 17:52:51 EDT)" (scheduled at 2024-05-14 17:50:51.032081-04:00)
# 2024-05-14 17:50:51,044 - INFO - Executing notebook to pull API data...
# 2024-05-14 17:50:51,046 - INFO - No changes detected in JSON file since last check or pipeline is still running.
# 2024-05-14 17:50:51,048 - INFO - Job "check_and_run_pipeline (trigger: interval[0:02:00], next run at: 2024-05-14 17:52:51 EDT)" executed successfully
# 2024-05-14 17:51:03,932 - INFO - File C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\VendorA.json has been modified
# 2024-05-14 17:51:03,933 - INFO - File C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\VendorA.json has been modified
# 2024-05-14 17:51:04,673 - INFO - Notebook execution completed.
# 2024-05-14 17:51:04,674 - INFO - Notebook Update: [NbConvertApp] Converting notebook C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\pull_vendor_api.ipynb to notebook
# [NbConvertApp] Writing 45911 bytes to C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\pull_vendor_api.ipynb
#
# 2024-05-14 17:51:04,675 - INFO - Job "run_notebook (trigger: interval[0:02:00], next run at: 2024-05-14 17:52:51 EDT)" executed successfully
# 2024-05-14 17:51:14,795 - INFO - File C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\VendorA.json has been modified
# 2024-05-14 17:51:14,796 - INFO - File C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\VendorA.json has been modified
# 2024-05-14 17:51:18,161 - INFO - File C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\VendorA.json has been modified
# 2024-05-14 17:51:18,163 - INFO - File C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\VendorA.json has been modified
# 2024-05-14 17:52:51,038 - INFO - Running job "run_notebook (trigger: interval[0:02:00], next run at: 2024-05-14 17:54:51 EDT)" (scheduled at 2024-05-14 17:52:51.030063-04:00)
# 2024-05-14 17:52:51,038 - INFO - Running job "check_and_run_pipeline (trigger: interval[0:02:00], next run at: 2024-05-14 17:54:51 EDT)" (scheduled at 2024-05-14 17:52:51.032081-04:00)
# 2024-05-14 17:52:51,040 - INFO - Executing notebook to pull API data...
# 2024-05-14 17:52:51,041 - INFO - No changes detected in JSON file since last check or pipeline is still running.
# 2024-05-14 17:52:51,043 - INFO - Job "check_and_run_pipeline (trigger: interval[0:02:00], next run at: 2024-05-14 17:54:51 EDT)" executed successfully
# 2024-05-14 17:53:05,372 - INFO - File C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\VendorA.json has been modified
# 2024-05-14 17:53:05,373 - INFO - File C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\VendorA.json has been modified
# 2024-05-14 17:53:06,210 - INFO - Notebook execution completed.
# 2024-05-14 17:53:06,211 - INFO - Notebook Update: [NbConvertApp] Converting notebook C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\pull_vendor_api.ipynb to notebook
# [NbConvertApp] Writing 47038 bytes to C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\pull_vendor_api.ipynb
#
# 2024-05-14 17:53:06,212 - INFO - Job "run_notebook (trigger: interval[0:02:00], next run at: 2024-05-14 17:54:51 EDT)" executed successfully
# 2024-05-14 17:54:51,034 - INFO - Running job "run_notebook (trigger: interval[0:02:00], next run at: 2024-05-14 17:56:51 EDT)" (scheduled at 2024-05-14 17:54:51.030063-04:00)
# 2024-05-14 17:54:51,035 - INFO - Executing notebook to pull API data...
# 2024-05-14 17:54:51,035 - INFO - Running job "check_and_run_pipeline (trigger: interval[0:02:00], next run at: 2024-05-14 17:56:51 EDT)" (scheduled at 2024-05-14 17:54:51.032081-04:00)
# 2024-05-14 17:54:51,038 - INFO - No changes detected in JSON file since last check or pipeline is still running.
# 2024-05-14 17:54:51,039 - INFO - Job "check_and_run_pipeline (trigger: interval[0:02:00], next run at: 2024-05-14 17:56:51 EDT)" executed successfully
# 2024-05-14 17:55:03,129 - INFO - File C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\VendorA.json has been modified
# 2024-05-14 17:55:03,674 - INFO - Notebook execution completed.
# 2024-05-14 17:55:03,675 - INFO - Notebook Update: [NbConvertApp] Converting notebook C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\pull_vendor_api.ipynb to notebook
# [NbConvertApp] Writing 47019 bytes to C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\pull_vendor_api.ipynb
#
# 2024-05-14 17:55:03,677 - INFO - Job "run_notebook (trigger: interval[0:02:00], next run at: 2024-05-14 17:56:51 EDT)" executed successfully
# 2024-05-14 17:56:51,034 - INFO - Running job "run_notebook (trigger: interval[0:02:00], next run at: 2024-05-14 17:58:51 EDT)" (scheduled at 2024-05-14 17:56:51.030063-04:00)
# 2024-05-14 17:56:51,034 - INFO - Running job "check_and_run_pipeline (trigger: interval[0:02:00], next run at: 2024-05-14 17:58:51 EDT)" (scheduled at 2024-05-14 17:56:51.032081-04:00)
# 2024-05-14 17:56:51,035 - INFO - Executing notebook to pull API data...
# 2024-05-14 17:56:51,037 - INFO - No changes detected in JSON file since last check or pipeline is still running.
# 2024-05-14 17:56:51,038 - INFO - Job "check_and_run_pipeline (trigger: interval[0:02:00], next run at: 2024-05-14 17:58:51 EDT)" executed successfully
# 2024-05-14 17:57:03,347 - INFO - File C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\VendorA.json has been modified
# 2024-05-14 17:57:03,347 - INFO - File C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\VendorA.json has been modified
# 2024-05-14 17:57:03,969 - INFO - Notebook execution completed.
# 2024-05-14 17:57:03,970 - INFO - Notebook Update: [NbConvertApp] Converting notebook C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\pull_vendor_api.ipynb to notebook
# [NbConvertApp] Writing 47019 bytes to C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\pull_vendor_api.ipynb
#
# 2024-05-14 17:57:03,971 - INFO - Job "run_notebook (trigger: interval[0:02:00], next run at: 2024-05-14 17:58:51 EDT)" executed successfully
