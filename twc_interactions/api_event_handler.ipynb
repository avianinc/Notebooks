# %%
import time
import subprocess
import os
from watchdog.observers import Observer
from watchdog.events import FileSystemEventHandler
from apscheduler.schedulers.background import BackgroundScheduler
import logging

# Setup logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# User-defined variables
DIRECTORY = r"C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\"
NOTEBOOK_FILE = "pull_vendor_api.ipynb"
JSON_FILE = "VendorA.json"
PIPELINE_FILE = "update_box.pipeline"

# Enable test mode
TEST_MODE = True

class ChangeHandler(FileSystemEventHandler):
    def __init__(self):
        self.file_changed = False

    def on_modified(self, event):
        if event.src_path == f"{DIRECTORY}{JSON_FILE}":
            logging.info(f"File {event.src_path} has been modified")
            self.file_changed = True

def run_notebook():
    logging.info("Executing notebook to pull API data...")
    result = subprocess.run(
        ["jupyter", "nbconvert", "--to", "notebook", "--execute", "--inplace", f"{DIRECTORY}{NOTEBOOK_FILE}"],
        capture_output=True, text=True)
    logging.info("Notebook execution completed.")
    if "Writing" in result.stderr:  # Check if it's a standard nbconvert output
        logging.info(f"Notebook Update: {result.stderr}")
    elif result.stderr:
        logging.error(f"Notebook Errors: {result.stderr}")

def check_and_run_pipeline():
    if event_handler.file_changed and not check_and_run_pipeline.is_running:
        check_and_run_pipeline.is_running = True
        logging.info("Change detected in JSON file, initiating Elyra pipeline...")
        
        pipeline_path = f"{DIRECTORY}{PIPELINE_FILE}"
        command = ["elyra-pipeline", "run", pipeline_path]
        
        if os.path.exists(pipeline_path):
            result = subprocess.run(command, capture_output=True, text=True)
            if result.stdout:
                logging.info(f"Pipeline Output: {result.stdout}")
            if result.stderr:
                logging.error(f"Pipeline Errors: {result.stderr}")
            if result.returncode != 0:
                logging.error("Failed to execute the pipeline.")
        else:
            logging.error(f"Pipeline file not found: {pipeline_path}")
        
        event_handler.file_changed = False
        check_and_run_pipeline.is_running = False
    else:
        logging.info("No changes detected in JSON file since last check or pipeline is still running.")

# Attach a flag to the function to monitor its running state
check_and_run_pipeline.is_running = False

if __name__ == "__main__":
    event_handler = ChangeHandler()
    observer = Observer()
    observer.schedule(event_handler, DIRECTORY, recursive=False)
    observer.start()

    scheduler = BackgroundScheduler()
    scheduler.add_job(run_notebook, 'interval', minutes=2)  # Adjusted to run every 2 minutes
    scheduler.add_job(check_and_run_pipeline, 'interval', minutes=2)
    scheduler.start()

    # Simulate a file change for testing purposes
    if TEST_MODE:
        time.sleep(5)  # Wait a few seconds before simulating
        logging.info("Test Mode: Simulating file change...")
        event_handler.file_changed = True  # Manually set the flag to simulate file change

    try:
        while True:
            time.sleep(1)
    except (KeyboardInterrupt, SystemExit):
        observer.stop()
        scheduler.shutdown()
    observer.join()
# Out:
# 2024-05-14 17:18:09,681 - INFO - Adding job tentatively -- it will be properly scheduled when the scheduler starts
# 2024-05-14 17:18:09,682 - INFO - Adding job tentatively -- it will be properly scheduled when the scheduler starts
# 2024-05-14 17:18:09,683 - INFO - Added job "run_notebook" to job store "default"
# 2024-05-14 17:18:09,684 - INFO - Added job "check_and_run_pipeline" to job store "default"
# 2024-05-14 17:18:09,685 - INFO - Scheduler started
# 2024-05-14 17:18:14,697 - INFO - Test Mode: Simulating file change...
# 2024-05-14 17:20:09,688 - INFO - Running job "run_notebook (trigger: interval[0:02:00], next run at: 2024-05-14 17:20:09 EDT)" (scheduled at 2024-05-14 17:20:09.681247-04:00)
# 2024-05-14 17:20:09,691 - INFO - Running job "check_and_run_pipeline (trigger: interval[0:02:00], next run at: 2024-05-14 17:22:09 EDT)" (scheduled at 2024-05-14 17:20:09.682247-04:00)
# 2024-05-14 17:20:09,692 - INFO - Executing notebook to pull API data...
# 2024-05-14 17:20:09,694 - INFO - Change detected in JSON file, initiating Elyra pipeline...
# 2024-05-14 17:20:09,713 - ERROR - Job "check_and_run_pipeline (trigger: interval[0:02:00], next run at: 2024-05-14 17:22:09 EDT)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\JohnDeHart\anaconda3\envs\twc_api_interactions\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "C:\Users\JohnDeHart\AppData\Local\Temp\ipykernel_38540\2841558460.py", line 50, in check_and_run_pipeline
#     result = subprocess.run(command, capture_output=True, text=True)
#   File "C:\Users\JohnDeHart\anaconda3\envs\twc_api_interactions\lib\subprocess.py", line 503, in run
#     with Popen(*popenargs, **kwargs) as process:
#   File "C:\Users\JohnDeHart\anaconda3\envs\twc_api_interactions\lib\subprocess.py", line 971, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "C:\Users\JohnDeHart\anaconda3\envs\twc_api_interactions\lib\subprocess.py", line 1456, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
# PermissionError: [WinError 5] Access is denied
# 2024-05-14 17:20:21,506 - INFO - File C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\VendorA.json has been modified
# 2024-05-14 17:20:21,510 - INFO - File C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\VendorA.json has been modified
# 2024-05-14 17:20:22,143 - INFO - Notebook execution completed.
# 2024-05-14 17:20:22,145 - INFO - Notebook Update: [NbConvertApp] Converting notebook C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\pull_vendor_api.ipynb to notebook
# [NbConvertApp] Writing 47048 bytes to C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\pull_vendor_api.ipynb
#
# 2024-05-14 17:20:22,146 - INFO - Job "run_notebook (trigger: interval[0:02:00], next run at: 2024-05-14 17:22:09 EDT)" executed successfully
# 2024-05-14 17:22:09,688 - INFO - Running job "run_notebook (trigger: interval[0:02:00], next run at: 2024-05-14 17:24:09 EDT)" (scheduled at 2024-05-14 17:22:09.681247-04:00)
# 2024-05-14 17:22:09,689 - INFO - Running job "check_and_run_pipeline (trigger: interval[0:02:00], next run at: 2024-05-14 17:24:09 EDT)" (scheduled at 2024-05-14 17:22:09.682247-04:00)
# 2024-05-14 17:22:09,692 - INFO - No changes detected in JSON file since last check or pipeline is still running.
# 2024-05-14 17:22:09,693 - INFO - Job "check_and_run_pipeline (trigger: interval[0:02:00], next run at: 2024-05-14 17:24:09 EDT)" executed successfully
# 2024-05-14 17:22:09,691 - INFO - Executing notebook to pull API data...
# 2024-05-14 17:22:22,130 - INFO - File C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\VendorA.json has been modified
# 2024-05-14 17:22:22,132 - INFO - File C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\VendorA.json has been modified
# 2024-05-14 17:22:22,690 - INFO - Notebook execution completed.
# 2024-05-14 17:22:22,691 - INFO - Notebook Update: [NbConvertApp] Converting notebook C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\pull_vendor_api.ipynb to notebook
# [NbConvertApp] Writing 47048 bytes to C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\pull_vendor_api.ipynb
#
# 2024-05-14 17:22:22,692 - INFO - Job "run_notebook (trigger: interval[0:02:00], next run at: 2024-05-14 17:24:09 EDT)" executed successfully
# 2024-05-14 17:24:09,688 - INFO - Running job "run_notebook (trigger: interval[0:02:00], next run at: 2024-05-14 17:26:09 EDT)" (scheduled at 2024-05-14 17:24:09.681247-04:00)
# 2024-05-14 17:24:09,688 - INFO - Running job "check_and_run_pipeline (trigger: interval[0:02:00], next run at: 2024-05-14 17:26:09 EDT)" (scheduled at 2024-05-14 17:24:09.682247-04:00)
# 2024-05-14 17:24:09,689 - INFO - Executing notebook to pull API data...
# 2024-05-14 17:24:09,690 - INFO - No changes detected in JSON file since last check or pipeline is still running.
# 2024-05-14 17:24:09,692 - INFO - Job "check_and_run_pipeline (trigger: interval[0:02:00], next run at: 2024-05-14 17:26:09 EDT)" executed successfully
# 2024-05-14 17:24:21,239 - INFO - File C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\VendorA.json has been modified
# 2024-05-14 17:24:21,240 - INFO - File C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\VendorA.json has been modified
# 2024-05-14 17:24:21,817 - INFO - Notebook execution completed.
# 2024-05-14 17:24:21,818 - INFO - Notebook Update: [NbConvertApp] Converting notebook C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\pull_vendor_api.ipynb to notebook
# [NbConvertApp] Writing 47048 bytes to C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\pull_vendor_api.ipynb
#
# 2024-05-14 17:24:21,819 - INFO - Job "run_notebook (trigger: interval[0:02:00], next run at: 2024-05-14 17:26:09 EDT)" executed successfully
# 2024-05-14 17:26:09,683 - INFO - Running job "run_notebook (trigger: interval[0:02:00], next run at: 2024-05-14 17:28:09 EDT)" (scheduled at 2024-05-14 17:26:09.681247-04:00)
# 2024-05-14 17:26:09,684 - INFO - Executing notebook to pull API data...
# 2024-05-14 17:26:09,683 - INFO - Running job "check_and_run_pipeline (trigger: interval[0:02:00], next run at: 2024-05-14 17:28:09 EDT)" (scheduled at 2024-05-14 17:26:09.682247-04:00)
# 2024-05-14 17:26:09,688 - INFO - No changes detected in JSON file since last check or pipeline is still running.
# 2024-05-14 17:26:09,689 - INFO - Job "check_and_run_pipeline (trigger: interval[0:02:00], next run at: 2024-05-14 17:28:09 EDT)" executed successfully
# 2024-05-14 17:26:21,512 - INFO - File C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\VendorA.json has been modified
# 2024-05-14 17:26:21,513 - INFO - File C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\VendorA.json has been modified
# 2024-05-14 17:26:22,065 - INFO - Notebook execution completed.
# 2024-05-14 17:26:22,068 - INFO - Notebook Update: [NbConvertApp] Converting notebook C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\pull_vendor_api.ipynb to notebook
# [NbConvertApp] Writing 47048 bytes to C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\pull_vendor_api.ipynb
#
# 2024-05-14 17:26:22,069 - INFO - Job "run_notebook (trigger: interval[0:02:00], next run at: 2024-05-14 17:28:09 EDT)" executed successfully
# 2024-05-14 17:28:09,685 - INFO - Running job "run_notebook (trigger: interval[0:02:00], next run at: 2024-05-14 17:30:09 EDT)" (scheduled at 2024-05-14 17:28:09.681247-04:00)
# 2024-05-14 17:28:09,687 - INFO - Executing notebook to pull API data...
# 2024-05-14 17:28:09,686 - INFO - Running job "check_and_run_pipeline (trigger: interval[0:02:00], next run at: 2024-05-14 17:30:09 EDT)" (scheduled at 2024-05-14 17:28:09.682247-04:00)
# 2024-05-14 17:28:09,690 - INFO - No changes detected in JSON file since last check or pipeline is still running.
# 2024-05-14 17:28:09,690 - INFO - Job "check_and_run_pipeline (trigger: interval[0:02:00], next run at: 2024-05-14 17:30:09 EDT)" executed successfully
# 2024-05-14 17:28:42,025 - INFO - Notebook execution completed.
# 2024-05-14 17:28:42,027 - ERROR - Notebook Errors: [NbConvertApp] Converting notebook C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\pull_vendor_api.ipynb to notebook
# Traceback (most recent call last):
#   File "C:\Users\JohnDeHart\anaconda3\envs\twc_api_interactions\Scripts\jupyter-nbconvert-script.py", line 9, in <module>
#     sys.exit(main())
#   File "C:\Users\JohnDeHart\anaconda3\envs\twc_api_interactions\lib\site-packages\jupyter_core\application.py", line 280, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "C:\Users\JohnDeHart\anaconda3\envs\twc_api_interactions\lib\site-packages\traitlets\config\application.py", line 992, in launch_instance
#     app.start()
#   File "C:\Users\JohnDeHart\anaconda3\envs\twc_api_interactions\lib\site-packages\nbconvert\nbconvertapp.py", line 412, in start
#     self.convert_notebooks()
#   File "C:\Users\JohnDeHart\anaconda3\envs\twc_api_interactions\lib\site-packages\nbconvert\nbconvertapp.py", line 590, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
#   File "C:\Users\JohnDeHart\anaconda3\envs\twc_api_interactions\lib\site-packages\nbconvert\nbconvertapp.py", line 556, in convert_single_notebook
#     output, resources = self.export_single_notebook(
#   File "C:\Users\JohnDeHart\anaconda3\envs\twc_api_interactions\lib\site-packages\nbconvert\nbconvertapp.py", line 479, in export_single_notebook
#     output, resources = self.exporter.from_filename(
#   File "C:\Users\JohnDeHart\anaconda3\envs\twc_api_interactions\lib\site-packages\nbconvert\exporters\exporter.py", line 203, in from_filename
#     return self.from_file(f, resources=resources, **kw)
#   File "C:\Users\JohnDeHart\anaconda3\envs\twc_api_interactions\lib\site-packages\nbconvert\exporters\exporter.py", line 222, in from_file
#     return self.from_notebook_node(
#   File "C:\Users\JohnDeHart\anaconda3\envs\twc_api_interactions\lib\site-packages\nbconvert\exporters\notebook.py", line 36, in from_notebook_node
#     nb_copy, resources = super().from_notebook_node(nb, resources, **kw)
#   File "C:\Users\JohnDeHart\anaconda3\envs\twc_api_interactions\lib\site-packages\nbconvert\exporters\exporter.py", line 156, in from_notebook_node
#     nb_copy, resources = self._preprocess(nb_copy, resources)
#   File "C:\Users\JohnDeHart\anaconda3\envs\twc_api_interactions\lib\site-packages\nbconvert\exporters\exporter.py", line 354, in _preprocess
#     nbc, resc = preprocessor(nbc, resc)  # type:ignore[operator]
#   File "C:\Users\JohnDeHart\anaconda3\envs\twc_api_interactions\lib\site-packages\nbconvert\preprocessors\base.py", line 48, in __call__
#     return self.preprocess(nb, resources)
#   File "C:\Users\JohnDeHart\anaconda3\envs\twc_api_interactions\lib\site-packages\nbconvert\preprocessors\execute.py", line 102, in preprocess
#     self.preprocess_cell(cell, resources, index)
#   File "C:\Users\JohnDeHart\anaconda3\envs\twc_api_interactions\lib\site-packages\nbconvert\preprocessors\execute.py", line 123, in preprocess_cell
#     cell = self.execute_cell(cell, index, store_history=True)
#   File "C:\Users\JohnDeHart\anaconda3\envs\twc_api_interactions\lib\site-packages\jupyter_core\utils\__init__.py", line 173, in wrapped
#     return loop.run_until_complete(inner)
#   File "C:\Users\JohnDeHart\anaconda3\envs\twc_api_interactions\lib\asyncio\base_events.py", line 649, in run_until_complete
#     return future.result()
#   File "C:\Users\JohnDeHart\anaconda3\envs\twc_api_interactions\lib\site-packages\nbclient\client.py", line 1058, in async_execute_cell
#     await self._check_raise_for_error(cell, cell_index, exec_reply)
#   File "C:\Users\JohnDeHart\anaconda3\envs\twc_api_interactions\lib\site-packages\nbclient\client.py", line 914, in _check_raise_for_error
#     raise CellExecutionError.from_cell_and_msg(cell, exec_reply_content)
# nbclient.exceptions.CellExecutionError: An error occurred while executing the following cell:
# ------------------
# # Ok so here is the wierd part... there is not direct way to extract the elements of a project (or model)
# # So we have to perform a 'diff' between the elements of the initial commit and the latest revision.
#
# # So lets get the latest revision number (or max revision number)
# # curl -X GET "https://18.205.77.131:8111/osmc/workspaces/bb95d8f4-fae4-490c-b764-4f83e3bba4f5/resources/272e28f2-45b7-45cb-a016-800ba747e716/revisions" -H "accept: application/json"
# call = f'/osmc/workspaces/{workspaceId}/resources/{projectId}/revisions'
# url = f'https://{serverIp}:{serverPort}{call}'
# resp_revList = requests.get(url,headers=headers, verify=False) # turn of verification here since our server is not super secure
# revisionList = resp_revList.json()
# latestRevision = max(revisionList)
# latestRevision
# ------------------
#
#
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\anaconda3\envs\twc_api_interactions\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~\anaconda3\envs\twc_api_interactions\lib\site-packages\urllib3\util\connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File ~\anaconda3\envs\twc_api_interactions\lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# File ~\anaconda3\envs\twc_api_interactions\lib\site-packages\urllib3\connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#
# File ~\anaconda3\envs\twc_api_interactions\lib\site-packages\urllib3\connectionpool.py:404, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     403 try:
# --> 404     self._validate_conn(conn)
#     405 except (SocketTimeout, BaseSSLError) as e:
#     406     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File ~\anaconda3\envs\twc_api_interactions\lib\site-packages\urllib3\connectionpool.py:1058, in HTTPSConnectionPool._validate_conn(self, conn)
#    1057 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1058     conn.connect()
#    1060 if not conn.is_verified:
#
# File ~\anaconda3\envs\twc_api_interactions\lib\site-packages\urllib3\connection.py:363, in HTTPSConnection.connect(self)
#     361 def connect(self):
#     362     # Add certificate verification
# --> 363     self.sock = conn = self._new_conn()
#     364     hostname = self.host
#
# File ~\anaconda3\envs\twc_api_interactions\lib\site-packages\urllib3\connection.py:179, in HTTPConnection._new_conn(self)
#     178 except SocketTimeout:
# --> 179     raise ConnectTimeoutError(
#     180         self,
#     181         "Connection to %s timed out. (connect timeout=%s)"
#     182         % (self.host, self.timeout),
#     183     )
#     185 except SocketError as e:
#
# ConnectTimeoutError: (<urllib3.connection.HTTPSConnection object at 0x000001FCD2B05150>, 'Connection to 10.107.1.92 timed out. (connect timeout=None)')
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File ~\anaconda3\envs\twc_api_interactions\lib\site-packages\urllib3\connectionpool.py:799, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     797     e = ProtocolError("Connection aborted.", e)
# --> 799 retries = retries.increment(
#     800     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     801 )
#     802 retries.sleep()
#
# File ~\anaconda3\envs\twc_api_interactions\lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='10.107.1.92', port=8111): Max retries exceeded with url: /osmc/workspaces/a2bf1c2f-03fb-4cbe-bb3d-4edce160916f/resources/5cb74688-9804-44b1-badb-4f09c5cb861e/revisions (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001FCD2B05150>, 'Connection to 10.107.1.92 timed out. (connect timeout=None)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                            Traceback (most recent call last)
# Cell In[9], line 8
#       6 call = f'/osmc/workspaces/{workspaceId}/resources/{projectId}/revisions'
#       7 url = f'https://{serverIp}:{serverPort}{call}'
# ----> 8 resp_revList = requests.get(url,headers=headers, verify=False) # turn of verification here since our server is not super secure
#       9 revisionList = resp_revList.json()
#      10 latestRevision = max(revisionList)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Roaming\Python\Python310\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\AppData\Roaming\Python\Python310\site-packages\requests\adapters.py:507, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     504 if isinstance(e.reason, ConnectTimeoutError):
#     505     # TODO: Remove this in 3.0.0: see #2811
#     506     if not isinstance(e.reason, NewConnectionError):
# --> 507         raise ConnectTimeout(e, request=request)
#     509 if isinstance(e.reason, ResponseError):
#     510     raise RetryError(e, request=request)
#
# ConnectTimeout: HTTPSConnectionPool(host='10.107.1.92', port=8111): Max retries exceeded with url: /osmc/workspaces/a2bf1c2f-03fb-4cbe-bb3d-4edce160916f/resources/5cb74688-9804-44b1-badb-4f09c5cb861e/revisions (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001FCD2B05150>, 'Connection to 10.107.1.92 timed out. (connect timeout=None)'))
#
#
# 2024-05-14 17:28:42,027 - INFO - Job "run_notebook (trigger: interval[0:02:00], next run at: 2024-05-14 17:30:09 EDT)" executed successfully
# 2024-05-14 17:30:09,689 - INFO - Running job "run_notebook (trigger: interval[0:02:00], next run at: 2024-05-14 17:32:09 EDT)" (scheduled at 2024-05-14 17:30:09.681247-04:00)
# 2024-05-14 17:30:09,691 - INFO - Executing notebook to pull API data...
# 2024-05-14 17:30:09,690 - INFO - Running job "check_and_run_pipeline (trigger: interval[0:02:00], next run at: 2024-05-14 17:32:09 EDT)" (scheduled at 2024-05-14 17:30:09.682247-04:00)
# 2024-05-14 17:30:09,693 - INFO - No changes detected in JSON file since last check or pipeline is still running.
# 2024-05-14 17:30:09,694 - INFO - Job "check_and_run_pipeline (trigger: interval[0:02:00], next run at: 2024-05-14 17:32:09 EDT)" executed successfully
# 2024-05-14 17:30:21,586 - INFO - File C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\VendorA.json has been modified
# 2024-05-14 17:30:21,588 - INFO - File C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\VendorA.json has been modified
# 2024-05-14 17:30:22,142 - INFO - Notebook execution completed.
# 2024-05-14 17:30:22,143 - INFO - Notebook Update: [NbConvertApp] Converting notebook C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\pull_vendor_api.ipynb to notebook
# [NbConvertApp] Writing 47048 bytes to C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\pull_vendor_api.ipynb
#
# 2024-05-14 17:30:22,144 - INFO - Job "run_notebook (trigger: interval[0:02:00], next run at: 2024-05-14 17:32:09 EDT)" executed successfully
# 2024-05-14 17:32:09,695 - INFO - Running job "run_notebook (trigger: interval[0:02:00], next run at: 2024-05-14 17:34:09 EDT)" (scheduled at 2024-05-14 17:32:09.681247-04:00)
# 2024-05-14 17:32:09,695 - INFO - Running job "check_and_run_pipeline (trigger: interval[0:02:00], next run at: 2024-05-14 17:34:09 EDT)" (scheduled at 2024-05-14 17:32:09.682247-04:00)
# 2024-05-14 17:32:09,697 - INFO - Executing notebook to pull API data...
# 2024-05-14 17:32:09,698 - INFO - No changes detected in JSON file since last check or pipeline is still running.
# 2024-05-14 17:32:09,700 - INFO - Job "check_and_run_pipeline (trigger: interval[0:02:00], next run at: 2024-05-14 17:34:09 EDT)" executed successfully
# 2024-05-14 17:32:22,051 - INFO - File C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\VendorA.json has been modified
# 2024-05-14 17:32:22,052 - INFO - File C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\VendorA.json has been modified
# 2024-05-14 17:32:22,774 - INFO - Notebook execution completed.
# 2024-05-14 17:32:22,775 - INFO - Notebook Update: [NbConvertApp] Converting notebook C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\\pull_vendor_api.ipynb to notebook
# [NbConvertApp] Writing 47048 bytes to C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\pull_vendor_api.ipynb
#
# 2024-05-14 17:32:22,776 - INFO - Job "run_notebook (trigger: interval[0:02:00], next run at: 2024-05-14 17:34:09 EDT)" executed successfully
