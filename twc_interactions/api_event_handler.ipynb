# %%
import time
import subprocess
import os
from watchdog.observers import Observer
from watchdog.events import FileSystemEventHandler
from apscheduler.schedulers.background import BackgroundScheduler
import logging

# Setup logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# User-defined variables
DIRECTORY = r"C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions"
JSON_FILE = "VendorA.json"
PIPELINE_FILE = "update_box.pipeline"
MAX_RETRIES = 10
RETRY_DELAY = 5  # seconds

class ChangeHandler(FileSystemEventHandler):
    def __init__(self):
        self.file_changed = False

    def on_modified(self, event):
        if event.src_path == f"{DIRECTORY}\\{JSON_FILE}":
            logging.info(f"File {event.src_path} has been modified")
            self.file_changed = True

def check_and_run_pipeline():
    if event_handler.file_changed:
        event_handler.file_changed = False  # Reset flag to avoid re-triggering during retries
        pipeline_path = f"{DIRECTORY}\\{PIPELINE_FILE}"
        command = ["elyra-pipeline", "run", pipeline_path]
        logging.info(f"Checking existence and attempting to execute command: {' '.join(command)}")

        if os.path.exists(pipeline_path):
            attempt = 0
            while attempt < MAX_RETRIES:
                try:
                    result = subprocess.run(command, capture_output=True, text=True, check=True)
                    logging.info(f"Pipeline executed successfully on attempt {attempt + 1}")
                    if result.stdout:
                        logging.info(f"Pipeline Output: {result.stdout}")
                    if result.stderr:
                        logging.error(f"Pipeline Errors: {result.stderr}")
                    break  # Successful execution, exit the loop
                except subprocess.CalledProcessError as e:
                    logging.error(f"Attempt {attempt + 1}: Pipeline execution failed: {e}")
                except Exception as e:
                    logging.error(f"Attempt {attempt + 1}: Unexpected error: {e}")
                attempt += 1
                if attempt < MAX_RETRIES:
                    logging.info(f"Retrying in {RETRY_DELAY} seconds...")
                    time.sleep(RETRY_DELAY)
        else:
            logging.error(f"Pipeline file not found: {pipeline_path}")
    else:
        logging.info("No changes detected or already processed.")



if __name__ == "__main__":
    event_handler = ChangeHandler()
    observer = Observer()
    observer.schedule(event_handler, DIRECTORY, recursive=True)
    observer.start()

    scheduler = BackgroundScheduler()
    scheduler.add_job(check_and_run_pipeline, 'interval', seconds=10)  # Adjust as needed
    scheduler.start()

    try:
        while True:
            time.sleep(1)
    except (KeyboardInterrupt, SystemExit):
        observer.stop()
        scheduler.shutdown()
    observer.join()
# Out:
# 2024-05-15 08:20:02,502 - INFO - Adding job tentatively -- it will be properly scheduled when the scheduler starts
# 2024-05-15 08:20:02,503 - INFO - Added job "check_and_run_pipeline" to job store "default"
# 2024-05-15 08:20:02,504 - INFO - Scheduler started
# 2024-05-15 08:20:12,512 - INFO - Running job "check_and_run_pipeline (trigger: interval[0:00:10], next run at: 2024-05-15 08:20:12 EDT)" (scheduled at 2024-05-15 08:20:12.502394-04:00)
# 2024-05-15 08:20:12,516 - INFO - No changes detected or already processed.
# 2024-05-15 08:20:12,517 - INFO - Job "check_and_run_pipeline (trigger: interval[0:00:10], next run at: 2024-05-15 08:20:22 EDT)" executed successfully
# 2024-05-15 08:20:15,130 - INFO - File C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\VendorA.json has been modified
# 2024-05-15 08:20:15,132 - INFO - File C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\VendorA.json has been modified
# 2024-05-15 08:20:15,133 - INFO - File C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\VendorA.json has been modified
# 2024-05-15 08:20:22,507 - INFO - Running job "check_and_run_pipeline (trigger: interval[0:00:10], next run at: 2024-05-15 08:20:32 EDT)" (scheduled at 2024-05-15 08:20:22.502394-04:00)
# 2024-05-15 08:20:22,508 - INFO - Checking existence and attempting to execute command: elyra-pipeline run C:\Users\JohnDeHart\Documents\GitHub\Notebooks\twc_interactions\update_box.pipeline
# 2024-05-15 08:20:32,502 - WARNING - Execution of job "check_and_run_pipeline (trigger: interval[0:00:10], next run at: 2024-05-15 08:20:32 EDT)" skipped: maximum number of running instances reached (1)
# 2024-05-15 08:20:34,744 - ERROR - Attempt 1: Unexpected error: [WinError 5] Access is denied
# 2024-05-15 08:20:34,745 - INFO - Retrying in 5 seconds...
# 2024-05-15 08:20:39,765 - ERROR - Attempt 2: Unexpected error: [WinError 5] Access is denied
# 2024-05-15 08:20:39,767 - INFO - Retrying in 5 seconds...
# 2024-05-15 08:20:42,509 - WARNING - Execution of job "check_and_run_pipeline (trigger: interval[0:00:10], next run at: 2024-05-15 08:20:42 EDT)" skipped: maximum number of running instances reached (1)
# 2024-05-15 08:20:44,783 - ERROR - Attempt 3: Unexpected error: [WinError 5] Access is denied
# 2024-05-15 08:20:44,785 - INFO - Retrying in 5 seconds...
# 2024-05-15 08:20:49,810 - ERROR - Attempt 4: Unexpected error: [WinError 5] Access is denied
# 2024-05-15 08:20:49,812 - INFO - Retrying in 5 seconds...
# 2024-05-15 08:20:54,829 - ERROR - Attempt 5: Unexpected error: [WinError 5] Access is denied
# 2024-05-15 08:20:54,831 - INFO - Retrying in 5 seconds...
# 2024-05-15 08:20:59,852 - ERROR - Attempt 6: Unexpected error: [WinError 5] Access is denied
# 2024-05-15 08:20:59,855 - INFO - Retrying in 5 seconds...
# 2024-05-15 08:21:04,866 - ERROR - Attempt 7: Unexpected error: [WinError 5] Access is denied
# 2024-05-15 08:21:04,867 - INFO - Retrying in 5 seconds...
# 2024-05-15 08:21:09,884 - ERROR - Attempt 8: Unexpected error: [WinError 5] Access is denied
# 2024-05-15 08:21:09,885 - INFO - Retrying in 5 seconds...
# 2024-05-15 08:21:14,900 - ERROR - Attempt 9: Unexpected error: [WinError 5] Access is denied
# 2024-05-15 08:21:14,902 - INFO - Retrying in 5 seconds...
# 2024-05-15 08:21:19,924 - ERROR - Attempt 10: Unexpected error: [WinError 5] Access is denied
# 2024-05-15 08:21:19,925 - INFO - Job "check_and_run_pipeline (trigger: interval[0:00:10], next run at: 2024-05-15 08:20:52 EDT)" executed successfully
# 2024-05-15 08:21:19,926 - ERROR - Error submitting job "check_and_run_pipeline (trigger: interval[0:00:10], next run at: 2024-05-15 08:20:52 EDT)" to executor "default"
# Traceback (most recent call last):
#   File "C:\Users\JohnDeHart\anaconda3\envs\twc_api_interactions\lib\site-packages\apscheduler\schedulers\base.py", line 988, in _process_jobs
#     executor.submit_job(job, run_times)
#   File "C:\Users\JohnDeHart\anaconda3\envs\twc_api_interactions\lib\site-packages\apscheduler\executors\base.py", line 71, in submit_job
#     self._do_submit_job(job, run_times)
#   File "C:\Users\JohnDeHart\anaconda3\envs\twc_api_interactions\lib\site-packages\apscheduler\executors\pool.py", line 28, in _do_submit_job
#     f = self._pool.submit(run_job, job, job._jobstore_alias, run_times, self._logger.name)
#   File "C:\Users\JohnDeHart\anaconda3\envs\twc_api_interactions\lib\concurrent\futures\thread.py", line 167, in submit
#     raise RuntimeError('cannot schedule new futures after shutdown')
# RuntimeError: cannot schedule new futures after shutdown
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 73
#      72     while True:
# ---> 73         time.sleep(1)
#      74 except (KeyboardInterrupt, SystemExit):
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 76
#      74 except (KeyboardInterrupt, SystemExit):
#      75     observer.stop()
# ---> 76     scheduler.shutdown()
#      77 observer.join()
#
# File ~\anaconda3\envs\twc_api_interactions\lib\site-packages\apscheduler\schedulers\background.py:41, in BackgroundScheduler.shutdown(self, *args, **kwargs)
#      40 def shutdown(self, *args, **kwargs):
# ---> 41     super(BackgroundScheduler, self).shutdown(*args, **kwargs)
#      42     self._thread.join()
#      43     del self._thread
#
# File ~\anaconda3\envs\twc_api_interactions\lib\site-packages\apscheduler\schedulers\blocking.py:24, in BlockingScheduler.shutdown(self, wait)
#      23 def shutdown(self, wait=True):
# ---> 24     super(BlockingScheduler, self).shutdown(wait)
#      25     self._event.set()
#
# File ~\anaconda3\envs\twc_api_interactions\lib\site-packages\apscheduler\schedulers\base.py:206, in BaseScheduler.shutdown(self, wait)
#     204 with self._executors_lock, self._jobstores_lock:
#     205     for executor in six.itervalues(self._executors):
# --> 206         executor.shutdown(wait)
#     208     # Shut down all job stores
#     209     for jobstore in six.itervalues(self._jobstores):
#
# File ~\anaconda3\envs\twc_api_interactions\lib\site-packages\apscheduler\executors\pool.py:37, in BasePoolExecutor.shutdown(self, wait)
#      36 def shutdown(self, wait=True):
# ---> 37     self._pool.shutdown(wait)
#
# File ~\anaconda3\envs\twc_api_interactions\lib\concurrent\futures\thread.py:235, in ThreadPoolExecutor.shutdown(self, wait, cancel_futures)
#     233 if wait:
#     234     for t in self._threads:
# --> 235         t.join()
#
# File ~\anaconda3\envs\twc_api_interactions\lib\threading.py:1096, in Thread.join(self, timeout)
#    1093     raise RuntimeError("cannot join current thread")
#    1095 if timeout is None:
# -> 1096     self._wait_for_tstate_lock()
#    1097 else:
#    1098     # the behavior of a negative timeout isn't documented, but
#    1099     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1100     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File ~\anaconda3\envs\twc_api_interactions\lib\threading.py:1116, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1113     return
#    1115 try:
# -> 1116     if lock.acquire(block, timeout):
#    1117         lock.release()
#    1118         self._stop()
#
# KeyboardInterrupt:
